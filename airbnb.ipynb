# %%
import pandas as pd

# %%
df_listing = pd.read_csv('Airbnb/listings.csv')
#
# Out:
# /var/folders/dp/8pdw35bs64q5shghwj6dt87w0000gn/T/ipykernel_35026/64520081.py:1: DtypeWarning: Columns (61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listing = pd.read_csv('Airbnb/listings.csv')

# %%
df_listing = df_listing.drop(columns=['scrape_id','last_scraped','summary','space','neighborhood_overview','transit'
                ,'access','interaction','thumbnail_url','notes','medium_url','picture_url','xl_picture_url','host_thumbnail_url',
                'host_picture_url','host_has_profile_pic', 'host_identity_verified','neighbourhood_cleansed','neighbourhood_group_cleansed',
                'market','smart_location','country_code','is_location_exact','minimum_minimum_nights','maximum_minimum_nights',
                'minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm',
                'availability_30','availability_60','availability_90','availability_365','calendar_last_scraped', 'number_of_reviews_ltm',
                'first_review','last_review', 'requires_license','license', 'jurisdiction_names', 'instant_bookable',
                'is_business_travel_ready', 'require_guest_profile_picture', 'require_guest_phone_verification', 'reviews_per_month',
                'calculated_host_listings_count','calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms'])

# %%
df_listing
# Out:
#              id                            listing_url  \
# 0         11551     https://www.airbnb.com/rooms/11551
# 1         38151     https://www.airbnb.com/rooms/38151
# 2         13913     https://www.airbnb.com/rooms/13913
# 3         38407     https://www.airbnb.com/rooms/38407
# 4         90700     https://www.airbnb.com/rooms/90700
# ...         ...                                    ...
# 85063  39868875  https://www.airbnb.com/rooms/39868875
# 85064  39869123  https://www.airbnb.com/rooms/39869123
# 85065  39869214  https://www.airbnb.com/rooms/39869214
# 85066  39869249  https://www.airbnb.com/rooms/39869249
# 85067  39869282  https://www.airbnb.com/rooms/39869282
#
#                                                     name  \
# 0             Arty and Bright London Apartment in Zone 2
# 1                                    Double room/ lounge
# 2                    Holiday London DB Room Let-on going
# 3                      Canary Wharf Immaculate Apt for 2
# ...

# %%
df_host = df_listing[['host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time',
                    'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
                    'host_total_listings_count','host_verifications']].copy()

# %%
df_host.shape
# Out:
# (85068, 14)

# %%
# we need to match df_listing columns with the df_listing_summary based on the listing id column
# This can be easily done usign sql scripts
# df_listing_summ = pd.read_csv('Airbnb/listings_summary.csv')
# df_listing_summ = df_listing_summ.drop(columns=['host_name','neighbourhood_group'])

# %%
df_pricing = df_listing[['price', 'weekly_price','monthly_price', 'security_deposit', 'cleaning_fee','extra_people', 'id']].copy()
# df_pricing.rename(columns={'id': 'listing_id'}, inplace=True)
df_pricing
# Out:
#          price weekly_price monthly_price security_deposit cleaning_fee  \
# 0       $88.00      $645.00     $2,350.00          $400.00       $30.00
# 1       $65.00          NaN           NaN              NaN          NaN
# 2       $65.00      $333.00     $1,176.00          $100.00       $15.00
# 3       $79.00      $530.00     $2,100.00              NaN          NaN
# 4      $105.00          NaN           NaN            $0.00       $35.00
# ...        ...          ...           ...              ...          ...
# 85063   $70.00          NaN           NaN          $200.00       $30.00
# 85064   $69.00          NaN           NaN          $200.00       $25.00
# 85065   $90.00          NaN           NaN              NaN       $55.00
# 85066   $30.00          NaN           NaN          $100.00       $10.00
# 85067  $187.00          NaN           NaN            $0.00       $30.00
#
#       extra_people        id
# 0           $20.00     11551
# 1            $0.00     38151
# ...

# %%
df_rating = df_listing[['number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value','id']].copy()
# df_pricing.rename(columns={'id': 'listing_id'}, inplace=True)
df_rating
# Out:
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                    185                  92.0                     9.0
# 1                      0                   NaN                     NaN
# 2                     19                  97.0                    10.0
# 3                    137                  95.0                     9.0
# 4                    339                  88.0                     9.0
# ...                  ...                   ...                     ...
# 85063                  0                   NaN                     NaN
# 85064                  0                   NaN                     NaN
# 85065                  0                   NaN                     NaN
# 85066                  0                   NaN                     NaN
# 85067                  0                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                            9.0                   10.0
# ...

# %%
df_listing = df_listing.drop(columns=['host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time',
                    'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
                    'host_total_listings_count','host_verifications', 'calculated_host_listings_count_shared_rooms', 'has_availability',
                    'calendar_updated', 'listing_url',
                    'price', 'weekly_price','monthly_price', 'security_deposit', 'cleaning_fee','extra_people',
                    'number_of_reviews', 'review_scores_rating','review_scores_accuracy', 'review_scores_cleanliness',
                    'review_scores_checkin', 'review_scores_communication','review_scores_location', 'review_scores_value'])

# %%
df_listing.shape
# Out:
# (85068, 27)

# %%
# reducing the size of calendar dataset
df_calendar = pd.read_csv('Airbnb/calendar.csv')
df_calendar.shape
# Out:
# (31050094, 7)

# %%
df_calendar = df_calendar.iloc[:100000]

# %%
df_calendar
# Out:
#        listing_id        date available    price adjusted_price  \
# 0           11551  2019-11-06         f  $105.00        $105.00
# 1           90700  2019-11-06         f  $125.00        $125.00
# 2           90700  2019-11-07         f  $125.00        $125.00
# 3           90700  2019-11-08         f  $125.00        $125.00
# 4           90700  2019-11-09         f  $125.00        $125.00
# ...           ...         ...       ...      ...            ...
# 99995      262294  2020-02-26         t   $99.00         $99.00
# 99996      262294  2020-02-27         t   $99.00         $99.00
# 99997      262294  2020-02-28         t   $99.00         $99.00
# 99998      262294  2020-02-29         t   $99.00         $99.00
# 99999      262294  2020-03-01         t   $99.00         $99.00
#
#        minimum_nights  maximum_nights
# 0                 3.0           180.0
# 1                90.0          1125.0
# 2                90.0          1125.0
# 3                90.0          1125.0
# ...

# %%
df_reviews = pd.read_csv('Airbnb/reviews.csv')
df_reviews.shape
# Out:
# (1486236, 6)

# %%
df_reviews = df_reviews.iloc[:100000]
df_reviews
# Out:
#        listing_id         id        date  reviewer_id reviewer_name  \
# 0           11551      30672  2010-03-21        93896      Shar-Lyn
# 1           11551      32236  2010-03-29        97890          Zane
# 2           90700     337227  2011-06-27       311071         Miqua
# 3           90700     378738  2011-07-17       224367       Prateek
# 4           90700     543840  2011-09-18      1115024      Jennifer
# ...           ...        ...         ...          ...           ...
# 99995      750364  536819634  2019-09-27     94177263       Cordell
# 99996      750364  538472211  2019-09-29     12458440       Aneessa
# 99997      750364  539504884  2019-10-01     58095939        Rachel
# 99998      750364  542629788  2019-10-06     29225494          Erin
# 99999      660064   77773175  2016-06-03      5773329        Kelsey
#
#                                                 comments
# 0      The flat was bright, comfortable and clean and...
# ...

# %%
# df_neighbourhood = pd.read_csv('Airbnb/neighbourhoods.csv')
# df_neighbourhood = df_neighbourhood.drop(columns=['neighbourhood_group'])
# df_neighbourhood.to_csv('postgresql/neighbourhood.csv')
df_neighbourhood = pd.DataFrame(df_listing['neighbourhood'].unique(), columns=['neighbourhood'])
# df_neighbourhood.rename(columns={'0': 'neighbourhood'})
df_neighbourhood
# Out:
#            neighbourhood
# 0                Brixton
# 1          LB of Croydon
# 2        LB of Islington
# 3    LB of Tower Hamlets
# 4           Notting Hill
# ..                   ...
# 145            Honor Oak
# 146           Grove Park
# 147         Putney Heath
# 148          Tooting Bec
# 149          St. James's
#
# [150 rows x 1 columns]

# %%
df_listing.to_csv('postgresql/listing.csv')

# %%
df_host.to_csv('postgresql/host.csv')

# %%
# df_listing_summ.to_csv('postgresql/listing_summary.csv')

# %%
df_calendar.to_csv('postgresql/calendar.csv')

# %%
df_reviews.to_csv('postgresql/reviews.csv')

# %%
df_pricing.to_csv('postgresql/pricing.csv')

# %%
df_rating.to_csv('postgresql/rating.csv')

# %%
# df_rating.to_sql()

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:testing@localhost:5432/London_Airbnb')

# df_host.drop_duplicates(subset='host_id', keep="first", inplace=True)
# df_host.to_sql('host', engine, index=False)

df_neighbourhood.index = df_neighbourhood.index + 1
df_neighbourhood.index.name = 'id'
df_neighbourhood.to_sql('neighbourhood', engine, index=True, if_exists='append')

# df_listing = df_listing.rename(columns={'id': 'listing_id'})
# df_listing.to_sql('listing', engine, index=False)

# df_calendar.index = df_calendar.index + 1
# df_calendar.index.name = 'id'
# df_calendar.to_sql('calendar', engine, index=True)

# df_pricing = df_pricing.rename(columns={'id': 'listing_id'})
# df_pricing.to_sql('pricing', engine, index=False)

# df_rating = df_rating.rename(columns={'id': 'listing_id'})
# df_rating.to_sql('rating', engine, index=False)

# df_reviews.drop_duplicates(subset='id', keep="first", inplace=True)
# df_reviews.to_sql('reviews', engine, index=False)
# Out:
# 150
